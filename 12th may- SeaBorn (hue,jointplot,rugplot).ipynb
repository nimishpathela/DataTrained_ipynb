# %%
import pandas as pd
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %%
tit=pd.read_csv('titanic_train.csv')
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sb.catplot(x='Pclass',y='Survived',hue='Sex',data=tit,kind='bar',) #hue can only be categpry column
sb.set(style='whitegrid')

# %%
sb.catplot(x='Pclass',y='Survived',hue='Sex',data=tit,kind='violin',) #hue can only be categpry column
sb.set(style='whitegrid')

# %%
sb.distplot(tit['Age'],bins=10) #curve is termed kde , if kide=false then curve wont appear
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sb.kdeplot(tit['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sb.jointplot(x='Age',y='Pclass',data=tit) #jointpl

# %%
sb.jointplot(x='Age',y='Pclass',data=tit,kind='kde') #kde= kernel density distribution

# %%
sb.rugplot(x='Age',y='Pclass',data=tit)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Pclass'>

# %%
sb.boxplot(x='Sex',y='Age',hue='Pclass',data=tit,palette='colorblind') #hue can only be categpry column
sb.set(style='whitegrid')

# %%
sb.pairplot(tit) #shows all the possible graphs using two variables

# %%
 sb.countplot('Pclass',data=tit) #first variable as treated as xaxis by default / no need to write axis= everytime
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sb.lmplot(x='Fare',y='Age',hue='Embarked',data=tit,palette='colorblind') #hue can only be categpry column
sb.set(style='whitegrid')

# %%
tit=tit.pivot('Age','Fare','PassengerId')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23928\1777805787.py in <module>
# ----> 1 tit=tit.pivot('Age','Fare','PassengerId')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    7883         from pandas.core.reshape.pivot import pivot
#    7884
# -> 7885         return pivot(self, index=index, columns=columns, values=values)
#    7886
#    7887     _shared_docs[
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     518         else:
#     519             indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 520     return indexed.unstack(columns_listlike)
#     521
#     522
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
# ...
